# %% [markdown]
# ### Jupyter Notebook
# - mode
#     - 명령모드 : 셀을 수정할때 사용
#     - 편집모드 : 셀 안의 내용을 수정할때 사용
# - style
#     - markdown : 셀안의 설명을 작성할때 사용
#     - code : python 코드를 작성할때 사용
# - 단축키
#     - 셀 실행 : shift + enter
#     - 셀 삭제 : x
#     - 되돌리기 : z
#     - 셀 생성 : 위 a , 아래 b

# %%
1+2
# Out:
# 3

# %% [markdown]
#     ### Magic command
#     - 셀 내부에서 특별하게 동작하는 커맨드
#     - % : 한줄의 magic command 를 동작
#     - %% : 셀단위의 magic command 를 동작
#     - 주요 magic command
#         - pwd 현재 주피터 노트북 파일의 경로
#         - ls : 현재 디렉토리의 파일리스트
#         - whos : 현재 선언된 변수를 출력
#         - reset : 현재 선언된 변수를 모두 삭제

# %%
# %pwd
# Out:
# Variable                        Type        Data/Info
# -----------------------------------------------------
# DataFrame                       type        <class 'pandas.core.frame.DataFrame'>
# MultiIndex                      type        <class 'pandas.core.indexes.multi.MultiIndex'>
# a                               int         1
# print_columns                   function    <function print_columns at 0x00000234DA85F790>
# pydev_jupyter_vars              module      <module 'pydev_jupyter_va<...>\\pydev_jupyter_vars.py'>
# remove_imported_pydev_package   function    <function remove_imported<...>ge at 0x00000234D92A2940>
# sys                             module      <module 'sys' (built-in)>
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 9AA4-2833
#
#  C:\Users\heo_d\IdeaProjects\py_prac 디렉터리
#
# 2022-05-14  오후 12:20    <DIR>          .
# 2022-05-14  오후 12:20    <DIR>          ..
# 2022-05-14  오후 12:16    <DIR>          .idea
# 2022-05-14  오후 12:20             4,436 1.ipynb
# ...

# %%
# %whos

# %%
a = 1

# %%
# %ls
# Out:
# Variable                        Type        Data/Info
# -----------------------------------------------------
# pydev_jupyter_vars              module      <module 'pydev_jupyter_va<...>\\pydev_jupyter_vars.py'>
# remove_imported_pydev_package   function    <function remove_imported<...>ge at 0x00000234D92A2940>
# sys                             module      <module 'sys' (built-in)>

# %%
# %reset
# Out:
# Nothing done.

# %%
# %whos

# %% [markdown]
# ### Shell Command
# - 주피터 노트북을 실행 쉘 환경의 명령을 사용
# - 명령어 앞에 !를 붙여서 실행
# - 주요 명령어
#     - ls, cat, echo...

# %%
# !echo python
# Out:
# python

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 9AA4-2833
#
#  C:\Users\heo_d\IdeaProjects\py_prac 디렉터리
#
# 2022-05-14  오후 12:23    <DIR>          .
# 2022-05-14  오후 12:23    <DIR>          ..
# 2022-05-14  오후 12:21    <DIR>          .idea
# 2022-05-14  오후 12:23             7,239 1.ipynb
# 2022-05-14  오전 11:55               389 py_prac.iml
# 2022-05-14  오전 11:59    <DIR>          venv
#                2개 파일               7,628 바이트
#                4개 디렉터리  36,650,627,072 바이트 남음
