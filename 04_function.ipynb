# %% [markdown]
# ### 함수
# - 반복되는 코드를 묶음으로 효율적인 코드를 작성하도록 해주는 기능
# - 기본 함수
# - 파라미터와 아규먼트
# - 리턴
# - `*args`, `**kwargs`
# - docstring
# - scope
# - inner function
# - lambda function
# - Map, Filter, Reduce
# - Decorlator

# %% [markdown]
# ### 1. 기본 함수
# - 함수의 선언과 호출

# %%
point = 88

if point >= 90:
    print("A")
elif point >= 80:
    print("B")
else:
    print("C")
# Out:
# B

# %%
# code ....

# %%
point = 70

if point >= 90:
    print("A")
elif point >= 80:
    print("B")
else:
    print("C")
# Out:
# C

# %%
# %reset

# %%
a = 1
ls = [1,2,3]

# %%
# %whos
# Out:
# Variable                        Type        Data/Info
# -----------------------------------------------------
# DataFrame                       type        <class 'pandas.core.frame.DataFrame'>
# MultiIndex                      type        <class 'pandas.core.indexes.multi.MultiIndex'>
# a                               int         1
# grade                           function    <function grade at 0x00000247CB600820>
# ls                              list        n=3
# print_columns                   function    <function print_columns at 0x00000247CB600B80>
# pydev_jupyter_vars              module      <module 'pydev_jupyter_va<...>\\pydev_jupyter_vars.py'>
# remove_imported_pydev_package   function    <function remove_imported<...>ge at 0x00000247C9CD33A0>
# sys                             module      <module 'sys' (built-in)>

# %%
# 함수선언
def grade(point):
     if point >= 90:
          print("A")
     elif point >= 80:
          print("B")
     else:
         print("C")

# %%
# 함수호출
grade(88)
# Out:
# B

# %%
# code ....

# %%
grade(78)
# Out:
# C

# %% [markdown]
# ### 2. 파라미터와 아규먼트
# - 파라미터 : 함수를 선언할때 호출하는 부분에서 보내주는 데이터를 받는 변수
# - 아규먼트 : 함수를 호출할때 함수에 보내주는 데이터

# %%
def plus(num1, num2=10, num3=20): #파라미터 : 디폴트 파라미터
    print(num1 + num2 - num3)

# %%
plus(1,2) #아규먼트
# Out:
# 3

# %%
plus(3,4)
# Out:
# 7

# %%
plus(2,2,3), #아규먼트
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1208/3524639393.py in <module>
# ----> 1 plus(2,2,3), #아규먼트
#
# TypeError: plus() takes from 1 to 2 positional arguments but 3 were given

# %%
plus(2) #아규먼트
# Out:
# 12

# %%
plus(3, num3 = 100) #아규먼트 : 키워드 아규먼트
# Out:
# -87

# %%
print(1, 2, end="-")
print(3)
# Out:
# 1 2-3

# %% [markdown]
# ### 3.리턴
# - 함수를 실행한 결과를 저장하고 싶을때 사용
# - return

# %%
def plus(num1, num2):
    print(num1 + num2)
    return num1 + num2

# %%
result = plus(1,2)
print(result)
# Out:
# 3
# 3

# %%
# 리턴이 있는 함수
data1 = "python"
result = data1.upper()
print(result)
# Out:
# PYTHON

# %%
# 리턴이 없는 함수
data2 = [3,1,2]
result = data2.sort()
print(result)
# Out:
# None

# %%
def grade(point):
    if point >= 90:
        return "A"
    elif point >= 80:
        return "B"
    else:
        return "C"

# %%
point = 92
result = grade(point)
print(result)
# Out:
# A

# %%
if result == "A":
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
# 함수에서 return 코드가 실행되면 무조건 함수의 코드 실행이 종료
def echo(msg):
    if msg == "quit":
        return
    print(msg)

# %%
echo("python")
# Out:
# python

# %%
echo("quit")

# %% [markdown]
# ### 4.`*args`, `**kwargs`
# - 함수를 호출할때 아규먼트와 키워드 아규먼트의 갯수를 특정지을수 없을떄 사용

# %%
def plus(*args):
    print(type(args),args)
    return sum(args)

# %%
plus(1, 2, 3, 4, 5)
# Out:
# <class 'tuple'> (1, 2, 3, 4, 5)
# 15

# %%
plus(1, 2, 3, 4, 5, num1=6, num2 =7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1208/3184382512.py in <module>
# ----> 1 plus(1, 2, 3, 4, 5, num1=6, num2 =7)
#
# TypeError: plus() got an unexpected keyword argument 'num1'

# %%
def plus(*args, **kwargs):
    print(type(args),args)
    print(type(kwargs),kwargs)
    return sum(args)

# %%
plus(1, 2, 3, 4, 5, num1=6, num2 =7)
# Out:
# <class 'tuple'> (1, 2, 3, 4, 5)
# <class 'dict'> {'num1': 6, 'num2': 7}
# 15

# %%
def func(num1, num2, num3):
    return num1 + num2 + num3
data = [1,2,3]
func(*data) # func(1, 2, 3)
# func(data) # func([1, 2, 3])
# Out:
# 6

# %%
data = {
    "num2" : 100,
    "num3" : 200,
}
func(1, **data) #func(1, num2=100, num3=200)
# Out:
# 301
