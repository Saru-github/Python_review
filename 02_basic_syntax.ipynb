# %% [markdown]
# ### 파이썬의 기본 문법
# - 변수 선언, 식별자, 자료형, 형변환, 연산자 학습

# %% [markdown]
# #### 1. 주석(comment)과 출력(print)

# %%
# 주석 : 앞에 #을 붙이면 코드로 실행이 안된다.
# 코드에 대한 설명이나 중간에 코드를 실행시키고 싶지 않을때 사용
# 단축키 : ctrl + /
# 블럭설정 : shift + 방향키

# 1,2,3 을 출력하는 코드
from psutil.tests import pyrun

print(1)
# print(2) #실행되지 않음.
print(3)
# Out:
# 1
# 3

# %%
# 출력 : print 함수
# 코드 중간에 변수안에 들어있는 값을 확인하고 싶을때 사용

# %%
a = 1
b = 2
print(b)
c = 3
b = 4
print(b)
for x in dict:
# Out:
# 2
# 4

# %%
# print 함수의 옵션
# docstring : 함수에 대한 설명 : 단축키(shift + tab)
# 자동완성 : tab
print(1,2, sep="-", end="\t")
print(3)
python_data = 1
# Out:
# 1-2	3

# %% [markdown]
# #### 변수 선언
# - RAM 저장공간에 값을 할당하는 행위

# %%
a = 1
b = 2
c = a+b
c
# Out:
# 3

# %%
d, e = 3, 4
f = g = 5

# %% [markdown]
# #### 3. 식별자
# - 변수, 함수, 클래스, 모듈등의 이름을 식별자 라고 함.
# - 식별자 규칙
#     - 소문자, 대문자, 숫자, 언더스코어(_)를 사용합니다.
#     - 가장 앞에 숫자 사용 불가
#     - 예약어의 사용불가 : def, class, try, except... 등
#     - 컨밴션
#         - snake case: fast_campus : 변수, 함수
#         - camel case: FastCampus, fastCapus : 클래스

# %%
# 10a =5
# def = 1

# %% [markdown]
# #### 4. 데이터 타입
# - RAM 저장공간을 효율적으로  사용하기 위해서 저장공간의 타입을 설정
# - 동적타이핑 : 변수 선언시 저장되는 값에 따라 자동으로 데이터 타입이 설정
# - 기본 데이터 타입 : in, float, bool, str
# - 컬렉션 데이터 타입: list, tuple, dict

# %%
a = 1
b = "python"
type(a), type(b)
# Out:
# (int, str)

# %%
# 기본 데이터 타입: int, float, bool, str
a = 1
b = 1.2
c = True #False
d = "data"
type(a), type(b), type(c), type(d)
# Out:
# (int, float, bool, str)

# %%
a + b , a+d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32928/1802875967.py in <module>
# ----> 1 a + b , a+d
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# 데이터 타입에 함수 : 문자열
# upper : 대문자로 변환
e=d.upper()

# %%
d, e
# Out:
# ('data', 'DATA')

# %%
f = " Fast campus "

# %%
# lower : 소문자로 변환
f.lower()
# Out:
# ' fast campus '

# %%
# strip : 공백제거
f.strip()
# Out:
# 'Fast campus'

# %%
# replace : 특정 문자열 치환
f.replace(" ", "")
f.replace("Fast", "Slow")
# Out:
# ' Slow campus '

# %%
# 함수 확인
dir(f)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
# 오프셋 인덱스 : 마스크, 마스킹 : []
# 문자열은 순서가 있는 문자들의 집합

# %%
g = "abcdefg"

# %%
g[2], g[-2], g[2:5], g[:2], g[3:], g[-2:], g[::2], g[::3], g[::-1]
# Out:
# ('c', 'f', 'cde', 'ab', 'defg', 'fg', 'aceg', 'adg', 'gfedcba')

# %%
numbers = "123456789" #97531 출력

# %%
numbers[::2][::-1]
# Out:
# '97531'

# %%
numbers[::-2]
# Out:
# '97531'

# %%
a = 1
b = 2
a + b
# Out:
# 3

# %%
a = 1
b = 2
print(a+b)
# Out:
# 3

# %% [markdown]
# #### 컬렉션 데이터 타입 : list, tuple, dict
# - list [] : 순서가 있는 수정이 가능한 데이터 타입
# - tuple () : 순서가 있는 수정이 불가능한 데이터 타입
# - dict {} : 순서가 없고 키:값 으로 구성되어 있는 데이터 타입

# %%
# list
ls = [1,2,3,"four",[5,6], True, 1.2]
type(ls), ls
# Out:
# (list, [1, 2, 3, 'four', [5, 6], True, 1.2])

# %%
# offset index 사용이 가능
ls[3], ls[1:3], ls[::-1]
# Out:
# ('four', [2, 3], [1.2, True, [5, 6], 'four', 3, 2, 1])

# %%
# list 함수

# %%
ls = [1,5,2,4]

# %%
# append : 가장 뒤에 값을 추가
ls.append(3)
ls
# Out:
# [1, 5, 2, 4, 3]

# %%
# sort : 오름차순으로 정렬
ls.sort()
ls
# Out:
# [1, 2, 3, 4, 5]

# %%
ls[::-1] # 내림차순 정렬
# Out:
# [5, 4, 3, 2, 1]

# %%
# pop : 가장 마지막 데이터를 출력하고 출력한 데이터를 삭제
num = ls.pop()
num, ls
# Out:
# (4, [1, 2, 3])

# %%
# 리스트의 복사

# %%
ls1 = [1,2,3]
ls2 = ls1       # 주소값 복사, 얕은 복사
ls1, ls2
# Out:
# ([1, 2, 3], [1, 2, 3])

# %%
ls1[2] = 5
ls1, ls2
# Out:
# ([1, 2, 5], [1, 2, 5])

# %%
ls3 = ls1.copy()

# %%
ls3[2] = 3

# %%
ls1, ls3
# Out:
# ([1, 2, 5], [1, 2, 3])

# %%
# Tuple (): 리스트와 같지만 수정이 불가능한 데이터 타입
# 튜플은 리스트보다 같은 데이터를 가졌을때 공간을 적게 사용

# %%
tp1 = 1,2,3
tp2 = (4,5,6)
type (tp1), type (tp2)
# Out:
# (tuple, tuple)

# %%
a,b =1,2
a,b
# Out:
# (1, 2)

# %%
# offset index 사용
tp1[2], tp1[::-1]
# Out:
# (3, (3, 2, 1))

# %%
# 리스트와 튜플의 저장공간 차이 비교
import sys

ls = [1,2,3]
tp = (1,2,3)

print(sys.getsizeof(ls), sys.getsizeof(tp))
# Out:
# 120 64

# %%
# dict {}
# 순서가 없고 {키:값} 으로 구성되어 있는 데이터 타입

# %%
# 선언 : 키는 정수, 문자열 데이터 타입만 사용이 가능
# 인덱스 대신 키를 사용

dic = {
    1: "one",
    "two" : 2,
    "three":[1,2,3],
}
type(dic), dic
# Out:
# (dict, {1: 'one', 'two': 2, 'three': [1, 2, 3]})

# %%
dic[1], dic["three"]
# Out:
# ('one', [1, 2, 3])

# %%
dic["two"]=123

# %%
dic
# Out:
# {1: 'one', 'two': 123, 'three': [1, 2, 3]}

# %%
# 도시 : seoul, busan, daegu
# 인구 : 9,700,000, 3,400,000, 2,400,000

# %%
# 리스트
city = ["seoul", "busan", "daegu"]
pop = [9700000, 3400000, 2400000]

# %%
# 딕셔너리
data = {
    "seoul": 9700000,
    "busan": 3400000,
    "daegu": 2400000,
}

# %%
sum(pop)
# Out:
# 15500000

# %%
sum([1,2,3])
# Out:
# 6

# %%
sum(data.values())
# Out:
# 15500000

# %% [markdown]
#  ### 5. 형변환
# - 데이터 타입을 변환하는 방법
# - int, float, bool, str, list, tuple, dict

# %%
a = 1
b = "2"
a+int(b)
# Out:
# 3

# %%
str(a)+b
# Out:
# '12'

# %%
type(data.values())
list(data.values())
# Out:
# [9700000, 3400000, 2400000]

# %%
city, pop
# Out:
# (['seoul', 'busan', 'daegu'], [9700000, 3400000, 2400000])

# %%
# zip : 같은 인덱스 데이터끼리 묶어주는 함수
list(zip(city, pop))
# Out:
# [('seoul', 9700000), ('busan', 3400000), ('daegu', 2400000)]

# %%
result=dict(list(zip(city, pop)))
result
# Out:
# {'seoul': 9700000, 'busan': 3400000, 'daegu': 2400000}

# %%
data1 = list(result.keys())
data2 = list(result.values())
data1, data2
# Out:
# (['seoul', 'busan', 'daegu'], [9700000, 3400000, 2400000])

# %%
string = "python"
int(string) # 에러
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32928/3612806910.py in <module>
#       1 string = "python"
# ----> 2 int(string)
#
# ValueError: invalid literal for int() with base 10: 'python'

# %% [markdown]
# ### 6. 연산자
# - 산술연산자: +, -, *, /, //, %, **
# - 할당연산자: 변수에 누적시켜서 연산 : +=, //=, **=...
# - 비교연산자: >, <, ==, !=, <=, >= : 결과로 Ture, False
# - 논리연산자: True, False 를 연산 : or, and, not
# - 멤버연산자: 특정 데이터가 있는지 확인할때 사용 : not in, in

# %%
a = 1
b = 2
a + b
# Out:
# 3

# %%
# 산술연산
(1 + 4) / 2 ** 2
# Out:
# 1.25

# %%
# 할당 연산
a = 10
a = a+ 10
a = a+ 10
a += 10
a += 10
a
# Out:
# 50

# %%
# 비교 연산
print(a,b)
a < b, a == b, a != b
# Out:
# 50 2
# (False, False, True)

# %%
# 논리 연산
True and False, True or False, not (True or False)
# Out:
# (False, True, False)

# %%
# 멤버 연산
ls = ["jin", "andy", "jhon"]

# %%
"andy" in ls, "anchel" in ls, "jhon" not in ls
# Out:
# (True, False, False)

# %%
### 랜덤함수
import  random

random.randint(1, 10)
# Out:
# 4

# %%
# 입력함수
data = input("insert string: ")
data
# Out:
# '하이염'

# %%
# 해결의 책 : 질문을 하면 질문에 대한 답변을 해주는 책
# 솔루션을 리스트로 작성
# 솔루션의 갯수에 맞게 랜덤한 index 정수 값을 새성
# index 해당하는 솔루션 리스트의 데이터를 출력

# %%
# 솔루션을 리스트로 작성
solutions = [
    "무엇을 하던 잘 될 것이다.",
    "생각지도 않게 좋은 일이 생길 것이다",
    "무엇이든 상상 이상이다.",
]

# 질문 입력 받음
input("질문을 입력하세요. :")

#솔루션의 갯수에 맞게 랜덤한 index 정수 값을 생성
idx = random.randint(0, len(solutions)-1)

solutions[idx]
# Out:
# '생각지도 않게 좋은 일이 생길 것이다'

# %%
len(solutions)
# Out:
# 3
